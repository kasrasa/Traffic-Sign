# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SeparableConv2D,Dense,BatchNormalization,MaxPool2D,Flatten,Dropout,Activation
from keras import backend as k
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

# %%
# %run build_dataset.py

# %%
X_test = test_images
X_train,X_val,y_train,y_val = train_test_split(training_images,labels,test_size=0.2,shuffle=True)
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (31367, 30, 30, 3)
# (7842, 30, 30, 3)
# (12630, 30, 30, 3)

# %%
num_classes = 43
y_train = to_categorical(y_train,num_classes = num_classes)
y_val = to_categorical(y_val,num_classes=num_classes)
print(y_train.shape,type(y_train))
print(y_val.shape,type(y_val))
# Out:
# (31367, 43) <class 'numpy.ndarray'>
# (7842, 43) <class 'numpy.ndarray'>

# %%
def convert_to_grid(x_input):
    N, H, W, C = x_input.shape
    grid_size = int(np.ceil(np.sqrt(N)))
    grid_height = H * grid_size + 1 * (grid_size - 1)
    grid_width = W * grid_size + 1 * (grid_size - 1)
    grid = np.zeros((grid_height, grid_width, C)) + 255
    next_idx = 0
    y0, y1 = 0, H
    for y in range(grid_size):
        x0, x1 = 0, W
        for x in range(grid_size):
            if next_idx < N:
                img = x_input[next_idx]
                low, high = np.min(img), np.max(img)
                grid[y0:y1, x0:x1] = 255.0 * (img - low) / (high - low)
                next_idx += 1
            x0 += W + 1
            x1 += W + 1
        y0 += H + 1
        y1 += H + 1

    return grid


# Visualizing some examples of training data
examples = X_train[:81, :, :, :]
print(examples.shape)  # (81, 32, 32, 3)

# Plotting some examples
fig = plt.figure()
grid = convert_to_grid(examples)
plt.imshow(grid.astype('uint8'), cmap='gray')
plt.axis('off')
plt.gcf().set_size_inches(15, 15)
plt.title('Some examples of training data', fontsize=18)

# Showing the plot
plt.show()
# Out:
# (81, 30, 30, 3)

# %%
class SignNet:
    @staticmethod
    def build(width,height,depth,classes):
        model = Sequential()
        input_shape = (height,width,depth)
        channel_dim = -1

        if k.image_data_format()=="channels_first": # in case the format of the image is reversed
            input_shape=(depth,height,width)
            channel_dim = 1
            
        model.add(SeparableConv2D(32,(3,3),input_shape = input_shape,padding = "same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis = channel_dim))
        model.add(SeparableConv2D(32,(3,3),padding = "same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis = channel_dim))
        model.add(MaxPool2D((2,2)))
        model.add(Dropout(0.25))

        model.add(Flatten())
        model.add(Dense(128))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis = channel_dim))
        model.add(Dropout(0.5))

        model.add(Dense(classes))
        model.add(Activation("softmax"))
        
        return model

# %%
num_epochs = 40
lr = 1e-3
bs = 32
model=SignNet.build(30,30,3,num_classes)
opt = Adam(learning_rate=lr,decay=lr/bs)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d_16 (Separab (None, 30, 30, 32)        155
# _________________________________________________________________
# activation_20 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# separable_conv2d_17 (Separab (None, 30, 30, 32)        1344
# _________________________________________________________________
# activation_21 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               921728
# _________________________________________________________________
# activation_22 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 43)                5547
# _________________________________________________________________
# activation_23 (Activation)   (None, 43)                0
# =================================================================
# Total params: 929,542
# Trainable params: 929,158
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.fit(X_train,y_train,batch_size=bs,epochs=num_epochs,validation_data=(X_val,y_val))
# Out:
# Epoch 1/40
# 981/981 [==============================] - 26s 27ms/step - loss: 0.8955 - accuracy: 0.7677 - val_loss: 0.1501 - val_accuracy: 0.9631
# Epoch 2/40
# 981/981 [==============================] - 26s 27ms/step - loss: 0.2036 - accuracy: 0.9440 - val_loss: 0.0717 - val_accuracy: 0.9813
# Epoch 3/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.1194 - accuracy: 0.9662 - val_loss: 0.0499 - val_accuracy: 0.9875
# Epoch 4/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0897 - accuracy: 0.9749 - val_loss: 0.0366 - val_accuracy: 0.9918
# Epoch 5/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0682 - accuracy: 0.9792 - val_loss: 0.0405 - val_accuracy: 0.9908
# Epoch 6/40
# 981/981 [==============================] - 26s 26ms/step - loss: 0.0561 - accuracy: 0.9827 - val_loss: 0.0277 - val_accuracy: 0.9936
# Epoch 7/40
# 981/981 [==============================] - 26s 26ms/step - loss: 0.0509 - accuracy: 0.9846 - val_loss: 0.0290 - val_accuracy: 0.9922
# Epoch 8/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0455 - accuracy: 0.9856 - val_loss: 0.0259 - val_accuracy: 0.9929
# Epoch 9/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.0294 - val_accuracy: 0.9915
# Epoch 10/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0303 - accuracy: 0.9908 - val_loss: 0.0244 - val_accuracy: 0.9944
# Epoch 11/40
# 981/981 [==============================] - 26s 26ms/step - loss: 0.0339 - accuracy: 0.9889 - val_loss: 0.0277 - val_accuracy: 0.9917
# Epoch 12/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0249 - accuracy: 0.9924 - val_loss: 0.0217 - val_accuracy: 0.9941
# Epoch 13/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0266 - accuracy: 0.9913 - val_loss: 0.0246 - val_accuracy: 0.9929
# Epoch 14/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0240 - accuracy: 0.9923 - val_loss: 0.0221 - val_accuracy: 0.9946
# Epoch 15/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.0228 - val_accuracy: 0.9944
# Epoch 16/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0191 - val_accuracy: 0.9949
# Epoch 17/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.0253 - val_accuracy: 0.9931
# Epoch 18/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.0216 - val_accuracy: 0.9931
# Epoch 19/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.0225 - val_accuracy: 0.9945
# Epoch 20/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.0188 - val_accuracy: 0.9950
# Epoch 21/40
# 981/981 [==============================] - 26s 26ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 0.0205 - val_accuracy: 0.9949
# Epoch 22/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.0160 - val_accuracy: 0.9963
# Epoch 23/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0148 - accuracy: 0.9953 - val_loss: 0.0173 - val_accuracy: 0.9960
# Epoch 24/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0164 - val_accuracy: 0.9958
# Epoch 25/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0128 - accuracy: 0.9954 - val_loss: 0.0195 - val_accuracy: 0.9946
# Epoch 26/40
# 981/981 [==============================] - 26s 26ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0156 - val_accuracy: 0.9964
# Epoch 27/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0203 - val_accuracy: 0.9943
# Epoch 28/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0145 - val_accuracy: 0.9963
# Epoch 29/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0159 - val_accuracy: 0.9960
# Epoch 30/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.0153 - val_accuracy: 0.9967
# Epoch 31/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0165 - val_accuracy: 0.9963
# Epoch 32/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0155 - val_accuracy: 0.9968
# Epoch 33/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0182 - val_accuracy: 0.9953
# Epoch 34/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0155 - val_accuracy: 0.9966
# Epoch 35/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.0198 - val_accuracy: 0.9950
# Epoch 36/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0181 - val_accuracy: 0.9952
# Epoch 37/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0160 - accuracy: 0.9955 - val_loss: 0.0149 - val_accuracy: 0.9960
# Epoch 38/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0175 - val_accuracy: 0.9957
# Epoch 39/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0135 - val_accuracy: 0.9969
# Epoch 40/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0162 - val_accuracy: 0.9963

# %%
plt.figure(0)
plt.plot(history.history['accuracy'],label=['training accuracy'])
plt.plot(history.history['val_accuracy'],label=['validation accuracy'])
plt.title('Train and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure(1)
plt.plot(history.history['loss'],label=['training loss'])
plt.plot(history.history['val_loss'],label=['validation loss'])
plt.title('Train and validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()

# %%
model=SignNet.build(30,30,3,num_classes)
opt = Adam(learning_rate=lr,decay=lr/bs)
earlystop = EarlyStopping(monitor = 'val_loss',min_delta = 0,patience = 3, verbose = 1,restore_best_weights = True)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics = ['accuracy'])
history = model.fit(X_train,y_train,batch_size=bs,epochs=num_epochs,validation_data=(X_val,y_val),callbacks=[earlystop])
# Out:
# Epoch 1/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.8382 - accuracy: 0.7815 - val_loss: 0.1275 - val_accuracy: 0.9711
# Epoch 2/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.1783 - accuracy: 0.9536 - val_loss: 0.0682 - val_accuracy: 0.9839
# Epoch 3/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.1096 - accuracy: 0.9696 - val_loss: 0.0426 - val_accuracy: 0.9912
# Epoch 4/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0815 - accuracy: 0.9770 - val_loss: 0.0427 - val_accuracy: 0.9884
# Epoch 5/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0621 - accuracy: 0.9817 - val_loss: 0.0359 - val_accuracy: 0.9913
# Epoch 6/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0520 - accuracy: 0.9838 - val_loss: 0.0520 - val_accuracy: 0.9842
# Epoch 7/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0464 - accuracy: 0.9857 - val_loss: 0.0285 - val_accuracy: 0.9920
# Epoch 8/40
# 981/981 [==============================] - 25s 26ms/step - loss: 0.0429 - accuracy: 0.9864 - val_loss: 0.0266 - val_accuracy: 0.9926
# Epoch 9/40
# 981/981 [==============================] - 26s 26ms/step - loss: 0.0347 - accuracy: 0.9900 - val_loss: 0.0268 - val_accuracy: 0.9923
# Epoch 10/40
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0303 - accuracy: 0.9906 - val_loss: 0.0272 - val_accuracy: 0.9926
# Epoch 11/40
# 980/981 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9898Restoring model weights from the end of the best epoch.
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0325 - accuracy: 0.9898 - val_loss: 0.0270 - val_accuracy: 0.9939
# Epoch 00011: early stopping

# %%
plt.figure(0)
plt.plot(history.history['accuracy'],label=['training accuracy'])
plt.plot(history.history['val_accuracy'],label=['validation accuracy'])
plt.title('Train and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure(1)
plt.plot(history.history['loss'],label=['training loss'])
plt.plot(history.history['val_loss'],label=['validation loss'])
plt.title('Train and validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()

# %%
X_test=test_images
y_test = test_table['ClassId'].values
print(X_test.shape)
print(y_test.shape)
plt.imshow(X_train[2])
# Out:
# (12630, 30, 30, 3)
# (12630,)

# %%
y_pred=model.predict_classes(X_test,verbose = 1)
# Out:
# 395/395 [==============================] - 2s 5ms/step

# %%
print(y_pred.shape)
print(y_test.shape)
print(classification_report(y_test,y_pred))
# Out:
# (12630,)
# (12630,)
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.85        60
#            1       0.97      0.95      0.96       720
#            2       0.92      0.99      0.95       750
#            3       0.88      0.97      0.93       450
#            4       0.97      0.96      0.97       660
#            5       0.90      0.91      0.90       630
#            6       0.98      0.86      0.91       150
#            7       0.97      0.93      0.95       450
#            8       0.94      0.91      0.93       450
#            9       0.96      0.99      0.98       480
#           10       0.99      0.97      0.98       660
#           11       0.94      0.96      0.95       420
#           12       1.00      1.00      1.00       690
#           13       0.99      1.00      0.99       720
#           14       1.00      1.00      1.00       270
#           15       0.99      0.98      0.99       210
#           16       1.00      0.99      0.99       150
#           17       1.00      1.00      1.00       360
#           18       0.93      0.93      0.93       390
#           19       0.79      0.73      0.76        60
#           20       0.75      0.91      0.82        90
#           21       0.84      0.91      0.87        90
#           22       0.98      0.98      0.98       120
#           23       0.77      0.89      0.83       150
#           24       0.86      0.92      0.89        90
#           25       0.96      0.95      0.96       480
#           26       0.91      0.82      0.86       180
#           27       0.95      0.58      0.72        60
#           28       0.97      0.98      0.97       150
#           29       0.97      0.98      0.97        90
#           30       0.96      0.73      0.83       150
#           31       0.96      0.97      0.96       270
#           32       1.00      1.00      1.00        60
#           33       0.99      1.00      0.99       210
#           34       0.95      0.98      0.97       120
#           35       1.00      0.99      0.99       390
#           36       0.98      0.97      0.97       120
#           37       1.00      0.95      0.97        60
#           38       0.98      0.99      0.98       690
#           39       0.98      0.98      0.98        90
#           40       0.99      0.87      0.92        90
#           41       0.72      0.77      0.74        60
#           42       0.99      0.79      0.88        90
#
#     accuracy                           0.95     12630
#    macro avg       0.94      0.92      0.93     12630
# weighted avg       0.96      0.95      0.95     12630
